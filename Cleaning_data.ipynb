# %%
import pandas as pd
uscities = pd.read_csv("uscities.csv")
income = pd.read_csv("Raw_Data/US_Income_Kaggle.csv")
Mental_Health = pd.read_csv("Raw_Data/500_Cities__Mental_health_not_good_for___14_days_among_adults_aged___18_years.csv")

# %%
uscities_order = ["city", "state_id", "state_name", "county_fips", "county_name", "population", "density", "military", "incorporated", "zips"]
uscities = uscities[uscities_order]
uscities
# Out:
#               city state_id  state_name  county_fips  county_name  population  \
# 0         New York       NY    New York        36061     New York    18713220
# 1      Los Angeles       CA  California         6037  Los Angeles    12750807
# 2          Chicago       IL    Illinois        17031         Cook     8604203
# 3            Miami       FL     Florida        12086   Miami-Dade     6445545
# 4           Dallas       TX       Texas        48113       Dallas     5743938
# ...            ...      ...         ...          ...          ...         ...
# 28333        Gross       NE    Nebraska        31015         Boyd           2
# 28334       Lotsee       OK    Oklahoma        40143        Tulsa           2
# 28335    The Ranch       MN   Minnesota        27087     Mahnomen           2
# 28336     Shamrock       OK    Oklahoma        40037        Creek           2
# 28337       Monowi       NE    Nebraska        31015         Boyd           1
#
# ...

# %%
# Eliminated missing row in Zips
zips = pd.notnull(uscities["zips"]) 
uscities = uscities[zips]
uscities_df = pd.DataFrame(uscities)
uscities_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 28337 entries, 0 to 28337
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   city          28337 non-null  object
#  1   state_id      28337 non-null  object
#  2   state_name    28337 non-null  object
#  3   county_fips   28337 non-null  int64
#  4   county_name   28337 non-null  object
#  5   population    28337 non-null  int64
#  6   density       28337 non-null  int64
#  7   military      28337 non-null  bool
#  8   incorporated  28337 non-null  bool
#  9   zips          28337 non-null  object
# dtypes: bool(2), int64(3), object(5)
# memory usage: 2.0+ MB

# %%
# #Investigating the Dataset
# uscities.loc[lambda uscities:uscities['military']==True]
# 85 results for military, worth keeping?

# uscities.loc[lambda uscities:uscities['incorporated']==True]

# %%
#Renaming the Columns and Displaying Info
uscities_df.rename(columns = {
    "city":"City",
    "state_id": "State Abreviation",
    "state_name":"State",
    "county_fips":"County_FIPS",
    "county_name":"County",
    "population":"Population",
    "density":"Population density",
    "military":"Military",
    "incorporated":"Incorporated",
    "zips":"List of Zip Codes"
    },inplace=True)
uscities_df
# Out:
#               City State Abreviation       State  County_FIPS       County  \
# 0         New York                NY    New York        36061     New York
# 1      Los Angeles                CA  California         6037  Los Angeles
# 2          Chicago                IL    Illinois        17031         Cook
# 3            Miami                FL     Florida        12086   Miami-Dade
# 4           Dallas                TX       Texas        48113       Dallas
# ...            ...               ...         ...          ...          ...
# 28333        Gross                NE    Nebraska        31015         Boyd
# 28334       Lotsee                OK    Oklahoma        40143        Tulsa
# 28335    The Ranch                MN   Minnesota        27087     Mahnomen
# 28336     Shamrock                OK    Oklahoma        40037        Creek
# 28337       Monowi                NE    Nebraska        31015         Boyd
#
#        Population  Population density  Military  Incorporated  \
# ...

# %%
income_order = ["id", "State_Name", "State_ab", "County", "City", "Zip_Code", "Area_Code", "ALand", "AWater", "Mean","Median","Stdev"]
income_df= income[income_order]
income_df
# Out:
#             id State_Name State_ab            County         City  Zip_Code  \
# 0       101901    Alabama       AL   Chambers County       Wadley     36276
# 1       101903    Alabama       AL  Jefferson County   Adamsville     35005
# 2       101905    Alabama       AL       Hale County        Akron     35541
# 3       101907    Alabama       AL   Marshall County  Albertville     35950
# 4       101909    Alabama       AL    Calhoun County   Alexandria     36250
# ...        ...        ...      ...               ...          ...       ...
# 15458  5601427    Wyoming       WY     Platte County    Wheatland     82201
# 15459  5601429    Wyoming       WY     Platte County    Wheatland     82201
# 15460  5601431    Wyoming       WY     Albany County      Laramie     82070
# 15461  5601433    Wyoming       WY   Campbell County       Wright     82732
# 15462  5601435    Wyoming       WY     Platte County    Wheatland     82201
#
# ...

# %%
#Renaming the Columns and Displaying Info
income_df.rename(columns = {
    "id":"Income ID",
    "State_Name": "State",
    "state_ab":"State Abreviation",
    "County":"County",
    "City":"City",
    "Zip_Code":"Zip Code",
    "Area_Code":"Area Code",
    "ALand":"Area of Land",
    "AWater":"Area of Water",
    "Mean":"Mean",
    "Median":"Median",
    "stdev":"Standard Deviation"
    },inplace=True)
income_df
# Out:
#        Income ID    State State_ab            County         City  Zip Code  \
# 0         101901  Alabama       AL   Chambers County       Wadley     36276
# 1         101903  Alabama       AL  Jefferson County   Adamsville     35005
# 2         101905  Alabama       AL       Hale County        Akron     35541
# 3         101907  Alabama       AL   Marshall County  Albertville     35950
# 4         101909  Alabama       AL    Calhoun County   Alexandria     36250
# ...          ...      ...      ...               ...          ...       ...
# 15458    5601427  Wyoming       WY     Platte County    Wheatland     82201
# 15459    5601429  Wyoming       WY     Platte County    Wheatland     82201
# 15460    5601431  Wyoming       WY     Albany County      Laramie     82070
# 15461    5601433  Wyoming       WY   Campbell County       Wright     82732
# 15462    5601435  Wyoming       WY     Platte County    Wheatland     82201
#
# ...

# %%
income.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15463 entries, 0 to 15462
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          15463 non-null  int64
#  1   State_Name  15463 non-null  object
#  2   State_ab    15463 non-null  object
#  3   County      15463 non-null  object
#  4   City        15463 non-null  object
#  5   Zip_Code    15463 non-null  int64
#  6   Area_Code   15463 non-null  int64
#  7   ALand       15463 non-null  int64
#  8   AWater      15463 non-null  int64
#  9   Mean        15463 non-null  float64
#  10  Median      15463 non-null  int64
#  11  Stdev       15463 non-null  object
# dtypes: float64(1), int64(6), object(5)
# memory usage: 1.4+ MB

# %%
Mental_Health_order = ["Year", "StateAbbr", "StateDesc", "CityName", "GeographicLevel", "Data_Value", "High_Confidence_Limit", "PopulationCount", "CityFIPS"]
Mental_Health = Mental_Health[Mental_Health_order]
Mental_Health
# Out:
#        Year StateAbbr    StateDesc      CityName GeographicLevel  Data_Value  \
# 0      2017        CT  Connecticut      Stamford            City        10.0
# 1      2017        IA         Iowa     Iowa City            City        13.2
# 2      2017        LA    Louisiana  Lake Charles            City        16.6
# 3      2017        MN    Minnesota   Minneapolis            City        11.4
# 4      2017        MN    Minnesota     Rochester            City        10.1
# ...     ...       ...          ...           ...             ...         ...
# 29001  2017        WI    Wisconsin     Milwaukee    Census Tract        18.4
# 29002  2017        WI    Wisconsin     Milwaukee    Census Tract        18.3
# 29003  2017        WI    Wisconsin     Milwaukee    Census Tract        19.7
# 29004  2017        WI    Wisconsin     Milwaukee    Census Tract        13.4
# 29005  2017        WI    Wisconsin       Madison    Census Tract        10.1
#
# ...

# %%
# Eliminated missing row in Zips
MH_data = pd.notnull(Mental_Health["Data_Value"]) 
Mental_Health = Mental_Health[MH_data]
MH_data = pd.notnull(Mental_Health["CityFIPS"]) 
Mental_Health = Mental_Health[MH_data]
MH_df = pd.DataFrame(Mental_Health)
MH_df
# Out:
#        Year StateAbbr    StateDesc      CityName GeographicLevel  Data_Value  \
# 0      2017        CT  Connecticut      Stamford            City        10.0
# 1      2017        IA         Iowa     Iowa City            City        13.2
# 2      2017        LA    Louisiana  Lake Charles            City        16.6
# 3      2017        MN    Minnesota   Minneapolis            City        11.4
# 4      2017        MN    Minnesota     Rochester            City        10.1
# ...     ...       ...          ...           ...             ...         ...
# 29001  2017        WI    Wisconsin     Milwaukee    Census Tract        18.4
# 29002  2017        WI    Wisconsin     Milwaukee    Census Tract        18.3
# 29003  2017        WI    Wisconsin     Milwaukee    Census Tract        19.7
# 29004  2017        WI    Wisconsin     Milwaukee    Census Tract        13.4
# 29005  2017        WI    Wisconsin       Madison    Census Tract        10.1
#
# ...

# %%
Mental_Health.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 28210 entries, 0 to 29005
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Year                   28210 non-null  int64
#  1   StateAbbr              28210 non-null  object
#  2   StateDesc              28210 non-null  object
#  3   CityName               28210 non-null  object
#  4   GeographicLevel        28210 non-null  object
#  5   Data_Value             28210 non-null  float64
#  6   High_Confidence_Limit  28210 non-null  float64
#  7   PopulationCount        28210 non-null  object
#  8   CityFIPS               28210 non-null  float64
# dtypes: float64(3), int64(1), object(5)
# memory usage: 2.2+ MB
